# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is 
great, and city is awesome. The sky is pinkish-blue. You shouldn't 
eat cardboard"""

# %%
tokenized_text=sent_tokenize(text)

# %%
 print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is \ngreat, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't \neat cardboard"]

# %%
from nltk.tokenize import word_tokenize

# %%
tokenized_word=word_tokenize(text)

# %%
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
from nltk.probability import FreqDist

# %%
fdist = FreqDist(tokenized_word)

# %%
print(fdist)
# Out:
# <FreqDist with 25 samples and 30 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('is', 3), (',', 2)]

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
 sent = "Albert Einstein was born in Ulm, Germany in 1879."

# %%
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

# tagged_tokens = nltk.pos_tag(tokens)
# print(tagged_tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
 from nltk.corpus import stopwords
 stop_words = set(stopwords.words("english"))
 print(stop_words)
# Out:
# {"she's", 'weren', 'hers', 'my', 'her', "it's", 'himself', 'off', 'wasn', 'while', 'the', 'through', "wasn't", 'about', 'will', 'being', 'that', 'did', 'their', "we've", 'ain', "she'll", "they've", 'needn', 'only', "we'd", 'ours', 'such', 'other', 'can', 'at', 'for', 'which', "that'll", 'both', "he'll", 'theirs', 'you', "i'll", 'd', "hasn't", 'itself', 'some', "wouldn't", 'is', 'are', 'above', 'once', 'any', 'in', 'yours', 'i', 'few', 'this', 've', 'down', 'wouldn', 'not', 'mightn', "weren't", 'where', 'more', 'same', "needn't", 'to', "we'll", 'because', 'doesn', 'shouldn', 'on', 'hasn', "i've", 'most', 'had', 'was', 'won', 'do', 'whom', "i'm", "haven't", 'how', "they'd", 'each', 'so', 'they', 'too', 'when', 'if', 'after', 'just', 'against', "he's", 'o', "aren't", "didn't", "won't", 'she', 'further', 'his', 'them', 'who', 'our', 'there', 'out', "they're", 'herself', 'its', 'no', 'be', 'under', 'why', 'below', "he'd", 'own', "it'd", 'during', 'it', "mustn't", 'what', "isn't", "you've", 'should', 'over', 'mustn', 'we', 'of', 'him', 'by', 'very', 'couldn', 'with', 're', "you'd", 'shan', 'but', 'have', "she'd", 't', 's', 'don', 'yourself', 'a', "it'll", "i'd", "don't", 'than', 'me', "mightn't", "they'll", "shan't", "doesn't", 'been', 'll', 'an', 'these', 'isn', 'here', "we're", 'were', 'ma', 'from', 'and', 'into', 'myself', 'all', 'themselves', 'before', 'until', 'm', 'now', "shouldn't", "you'll", "couldn't", 'doing', 'has', 'up', "you're", 'ourselves', 'y', "should've", 'those', "hadn't", 'yourselves', 'between', 'hadn', 'having', 'as', 'again', 'your', 'haven', 'he', 'then', 'am', 'or', 'nor', 'aren', 'didn', 'does'}

# %%
import nltk
from nltk.corpus import stopwords
tokenized_sent = ["This", "is", "a", "sample", "sentence", "with", "some", "stop"]
stop_words = set(stopwords.words("english"))
filtered_sent = []
for w in tokenized_sent:
  if w.lower() not in stop_words:
    filtered_sent.append(w)
print("Filtered Sentence:", filtered_sent)
print("Tokenized Sentence:", tokenized_sent)
# Out:
# Filtered Sentence: ['sample', 'sentence', 'stop']
# Tokenized Sentence: ['This', 'is', 'a', 'sample', 'sentence', 'with', 'some', 'stop']

# %%
 from nltk.stem.wordnet import WordNetLemmatizer
 lem = WordNetLemmatizer()
 from nltk.stem.porter import PorterStemmer
 stem = PorterStemmer()
 word = "flying" 
 print("Lemmatized Word:",lem.lemmatize(word,"v")) 
 print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: fly
# Stemmed Word: fli
